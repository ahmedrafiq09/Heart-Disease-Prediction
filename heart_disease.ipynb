# %%
#Import All Libraries 
import numpy as np
import seaborn as sns
import pandas as pd
from matplotlib import pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.preprocessing import LabelEncoder
from sklearn.ensemble import RandomForestClassifier

# %%
df = pd.read_csv("heart.csv")                               #Read CSV File 
df
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA        140          289          0     Normal
# 1     49   F           NAP        160          180          0     Normal
# 2     37   M           ATA        130          283          0         ST
# 3     48   F           ASY        138          214          0     Normal
# 4     54   M           NAP        150          195          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 916   57   F           ATA        130          236          0        LVH
# 917   38   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# ...

# %%
y = df.HeartDisease
y
# Out:
# 0      0
# 1      1
# 2      0
# 3      1
# 4      0
#       ..
# 913    1
# 914    1
# 915    1
# 916    1
# 917    0
# Name: HeartDisease, Length: 918, dtype: int64

# %%
X = df.drop('HeartDisease', axis=1)                             #Drop the Labels of The Dataset
X
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA        140          289          0     Normal
# 1     49   F           NAP        160          180          0     Normal
# 2     37   M           ATA        130          283          0         ST
# 3     48   F           ASY        138          214          0     Normal
# 4     54   M           NAP        150          195          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 916   57   F           ATA        130          236          0        LVH
# 917   38   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope
# 0      172              N      0.0       Up
# ...

# %%
#Use label Encoder to Conver The String Data To Int
le_Sex = LabelEncoder()
le_ChestPainType = LabelEncoder()
le_RestingECG = LabelEncoder()
le_ExerciseAngina = LabelEncoder()
le_ST_Slope = LabelEncoder()

# %%
X['new_sex'] = le_Sex.fit_transform(X['Sex'])
X['new_ChestPainType'] = le_ChestPainType.fit_transform(X['ChestPainType'])
X['new_RestingECG'] = le_RestingECG.fit_transform(X['RestingECG'])
X['new_ExerciseAngina'] = le_ExerciseAngina.fit_transform(X['ExerciseAngina'])
X['new_ST_Slope'] = le_ST_Slope.fit_transform(X["ST_Slope"])

# %%
X
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA        140          289          0     Normal
# 1     49   F           NAP        160          180          0     Normal
# 2     37   M           ATA        130          283          0         ST
# 3     48   F           ASY        138          214          0     Normal
# 4     54   M           NAP        150          195          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 916   57   F           ATA        130          236          0        LVH
# 917   38   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  new_sex  new_ChestPainType  \
# ...

# %%
X = X.drop(['Sex','ChestPainType','RestingECG','ExerciseAngina','ST_Slope'], axis=1)
X
# Out:
#      Age  RestingBP  Cholesterol  FastingBS  MaxHR  Oldpeak  new_sex  \
# 0     40        140          289          0    172      0.0        1
# 1     49        160          180          0    156      1.0        0
# 2     37        130          283          0     98      0.0        1
# 3     48        138          214          0    108      1.5        0
# 4     54        150          195          0    122      0.0        1
# ..   ...        ...          ...        ...    ...      ...      ...
# 913   45        110          264          0    132      1.2        1
# 914   68        144          193          1    141      3.4        1
# 915   57        130          131          0    115      1.2        1
# 916   57        130          236          0    174      0.0        0
# 917   38        138          175          0    173      0.0        1
#
#      new_ChestPainType  new_RestingECG  new_ExerciseAngina  new_ST_Slope
# ...

# %%
X_train,X_test,y_train,y_test = train_test_split(X.values, y, test_size=0.1)

# %%
print(len(X_train))
print(len(X_test))
print(len(y_train))
print(len(y_test))
# Out:
# 826
# 92
# 826
# 92

# %%
model = RandomForestClassifier()
model.fit(X_train,y_train)
# Out:
# RandomForestClassifier()

# %%
model.score(X_test,y_test)
# Out:
# 0.8695652173913043

# %%
model.predict([[227, 230, 332, 0, 298, 0.0, 2219, 21, 2233, 0, 22]])
# Out:
# array([1], dtype=int64)

# %%
if model.predict([[227, 230, 332, 0, 298, 0.0, 2219, 21, 2233, 0, 22]])[0] == 1:
 print("Having heart disease")
else:
 print("Not having heart disease")
# Out:
# Having heart disease
